# %% [markdown]
# # Some basic observation

# %%
import pandas as pd 
df = pd.read_csv("Dataset/5f_label_loc_train.csv")

# %%
df.shape
# Out:
# (1334, 11)

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  activity                 started_at  \
# 0           170         170  Location  2023-04-10 14:21:46+09:00
# 1           171         171  Location  2023-04-10 14:21:55+09:00
# 2           172         172  Location  2023-04-10 14:22:23+09:00
# 3           173         173  Location  2023-04-10 14:23:29+09:00
# 4           174         174  Location  2023-04-10 14:23:42+09:00
#
#                  finished_at deleted_at               updated_at  user_id  \
# 0  2023-04-10 14:21:50+09:00        NaN  2023-04-10 05:22:02 UTC       97
# 1  2023-04-10 14:22:16+09:00        NaN  2023-04-10 05:23:02 UTC       97
# 2  2023-04-10 14:23:25+09:00        NaN  2023-04-10 05:24:01 UTC       97
# 3  2023-04-10 14:23:44+09:00        NaN  2023-04-10 05:24:02 UTC       97
# 4  2023-04-10 14:24:05+09:00        NaN  2023-04-10 05:25:03 UTC       97
#
#            user           room floor
# 0  5th-location        kitchen   5th
# 1  5th-location      cafeteria   5th
# 2  5th-location        kitchen   5th
# 3  5th-location       cleaning   5th
# 4  5th-location  nurse station   5th

# %% [markdown]
# # Data cleaning

# %%
# Firstly count number of records with NaN value for userid column 
df['user_id'].isnull().sum().sum()
# Out:
# np.int64(0)

# %%
# drop the two unnamed/index columns and add placeholders
df.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'], inplace=True)

# %%
# just take the record with activity to be "Location"
df = df.loc[df['activity'] == 'Location']

# display head 
df.head()
# Out:
#    activity                 started_at                finished_at deleted_at  \
# 0  Location  2023-04-10 14:21:46+09:00  2023-04-10 14:21:50+09:00        NaN
# 1  Location  2023-04-10 14:21:55+09:00  2023-04-10 14:22:16+09:00        NaN
# 2  Location  2023-04-10 14:22:23+09:00  2023-04-10 14:23:25+09:00        NaN
# 3  Location  2023-04-10 14:23:29+09:00  2023-04-10 14:23:44+09:00        NaN
# 4  Location  2023-04-10 14:23:42+09:00  2023-04-10 14:24:05+09:00        NaN
#
#                 updated_at  user_id          user           room floor
# 0  2023-04-10 05:22:02 UTC       97  5th-location        kitchen   5th
# 1  2023-04-10 05:23:02 UTC       97  5th-location      cafeteria   5th
# 2  2023-04-10 05:24:01 UTC       97  5th-location        kitchen   5th
# 3  2023-04-10 05:24:02 UTC       97  5th-location       cleaning   5th
# 4  2023-04-10 05:25:03 UTC       97  5th-location  nurse station   5th

# %%
# filter the records with NaN value in started_at / finished_at or 
# un-NaN value in deleted_at (this means that this record is 
# intended to be deleted, not to be used)
df = df[
    df['started_at'].notna() &  # Keep only records where started_at is not NaN
    df['finished_at'].notna() &  # Keep only records where finished_at is not NaN
    df['deleted_at'].isna()      # Keep only records where deleted_at IS NaN (not deleted)
]

# %%
# okay done now we can safely drop the extra columns: deleted_at 
# and updated_at 
df.drop(columns=['deleted_at', 'updated_at'], inplace=True)

# %%
# now just keep the record with user id == 97, as we just care 
# about 5th floor 
df = df.loc[df['user_id'] == 97]

df.head()
# Out:
#    activity                 started_at                finished_at  user_id  \
# 0  Location  2023-04-10 14:21:46+09:00  2023-04-10 14:21:50+09:00       97
# 1  Location  2023-04-10 14:21:55+09:00  2023-04-10 14:22:16+09:00       97
# 2  Location  2023-04-10 14:22:23+09:00  2023-04-10 14:23:25+09:00       97
# 3  Location  2023-04-10 14:23:29+09:00  2023-04-10 14:23:44+09:00       97
# 4  Location  2023-04-10 14:23:42+09:00  2023-04-10 14:24:05+09:00       97
#
#            user           room floor
# 0  5th-location        kitchen   5th
# 1  5th-location      cafeteria   5th
# 2  5th-location        kitchen   5th
# 3  5th-location       cleaning   5th
# 4  5th-location  nurse station   5th

# %%
# check the possible values for "user" and "floor" features --> need to ensure all are 5th floor
df["user"].value_counts()
# Out:
# user
# 5th-location    451
# Name: count, dtype: int64

# %%
df["floor"].value_counts()
# Out:
# floor
# 5th        410
# 2nd,5th     41
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (451, 7)

# %%
# Okay now verify the final df once again before save it to 
# a cleaned csv file
df.head()
# Out:
#    activity                 started_at                finished_at  user_id  \
# 0  Location  2023-04-10 14:21:46+09:00  2023-04-10 14:21:50+09:00       97
# 1  Location  2023-04-10 14:21:55+09:00  2023-04-10 14:22:16+09:00       97
# 2  Location  2023-04-10 14:22:23+09:00  2023-04-10 14:23:25+09:00       97
# 3  Location  2023-04-10 14:23:29+09:00  2023-04-10 14:23:44+09:00       97
# 4  Location  2023-04-10 14:23:42+09:00  2023-04-10 14:24:05+09:00       97
#
#            user           room floor
# 0  5th-location        kitchen   5th
# 1  5th-location      cafeteria   5th
# 2  5th-location        kitchen   5th
# 3  5th-location       cleaning   5th
# 4  5th-location  nurse station   5th

# %%
# save to a new csv file
df.to_csv("cleaned_dataset/cleaned_label_loc.csv")
